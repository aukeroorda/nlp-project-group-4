# %%
import numpy as np
from plot_utils import *

# %%
train_losses_fine_ger = np.load("../train_losses_fine_ger.npy")
valid_losses_fine_ger = np.load("../valid_losses_fine_ger.npy")

train_losses_fine_tur = np.load("../train_losses_fine_tur.npy")
valid_losses_fine_tur = np.load("../valid_losses_fine_tur.npy")

train_losses_scratch_ger = np.load("../train_losses_scratch_ger.npy")
valid_losses_scratch_ger = np.load("../valid_losses_scratch_ger.npy")

train_losses_scratch_tur = np.load("../train_losses_scratch_tur.npy")
valid_losses_scratch_tur = np.load("../valid_losses_scratch_tur.npy")

# %%
fig_1 = plot_losses_2(valid_losses_fine_ger, 
                      valid_losses_scratch_ger, 
                      title="Comparison of validation loss for German dataset",
                      label_1="loss for the finetuned model",
                      label_2="loss for the model trained from scratch")
fig_1.show()
# Out:
# /tmp/ipykernel_69199/2740679655.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_1.show()

# %%
fig_2 = plot_losses_2(valid_losses_fine_tur, 
                      valid_losses_scratch_tur, 
                      title="Comparison of validation loss for Turkish dataset",
                      label_1="loss for the finetuned model",
                      label_2="loss for the model trained from scratch")
fig_2.show()
# Out:
# /tmp/ipykernel_69199/1704837484.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_2.show()
