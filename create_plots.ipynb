# %%
import numpy as np
from plot_utils import *

# %%
train_losses_fine_ger = np.load("../train_losses_fine_ger.npy")
valid_losses_fine_ger = np.load("../valid_losses_fine_ger.npy")

train_losses_fine_tur = np.load("../train_losses_fine_tur.npy")
valid_losses_fine_tur = np.load("../valid_losses_fine_tur.npy")

train_losses_scratch_ger = np.load("../train_losses_scratch_ger.npy")
valid_losses_scratch_ger = np.load("../valid_losses_scratch_ger.npy")

train_losses_scratch_tur = np.load("../train_losses_scratch_tur.npy")
valid_losses_scratch_tur = np.load("../valid_losses_scratch_tur.npy")

# %%
list_losses_ger = [
    train_losses_fine_ger, 
    valid_losses_fine_ger, 
    train_losses_scratch_ger, 
    valid_losses_scratch_ger,
]

list_labels_ger = [
    "train losses - finetuned",
    "validation losses - finetuned",
    "train losses - scratch",
    "validation losses - scratch",
]

# %%
fig_1 = plot_losses_multi(list_losses_ger, 
                          title="Comparison of losses for German dataset",
                          list_of_labels=list_labels_ger,
                          start_epoch=5)
fig_1.show()
# Out:
# /tmp/ipykernel_96119/1281660733.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_1.show()

# %%
list_losses_tur = [
    train_losses_fine_tur, 
    valid_losses_fine_tur, 
    train_losses_scratch_tur, 
    valid_losses_scratch_tur,
]

list_labels_tur = [
    "train losses - finetuned",
    "validation losses - finetuned",
    "train losses - scratch",
    "validation losses - scratch",
]

# %%
fig_2 = plot_losses_multi(list_losses_tur, 
                          title="Comparison of losses for Turkish dataset",
                          list_of_labels=list_labels_tur,
                          start_epoch=5)
fig_2.show()
# Out:
# /tmp/ipykernel_96119/951985299.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_2.show()
